# %%
# %pip install python-chess

# %%
import chess

FEN = "2kr3r/1ppbnp2/1b6/q6N/P2pPNp1/3P2P1/2P3BP/R2Q1RK1 b - - 0 23"

board = chess.Board(FEN)
board

# %%
print(board)

# %%
import chess.svg
board_svg = chess.svg.board(board=board)

# %%
print(board_svg)
